# %% [markdown]
# # **Concepts:**<br>
# Margin, kernels, linear/non-linear classification, Dimensionality Reduction using PCA

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-c44b1dce-7c63-470e-8dd2-b997424e6bb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c44b1dce-7c63-470e-8dd2-b997424e6bb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import all necessary libraries
import pandas as pd                 # For data manipulation
import numpy as np                  # For numerical computations
import seaborn as sns               # For advanced visualizations
import matplotlib.pyplot as plt     # For basic plotting
import warnings
from sklearn import preprocessing

from sklearn.svm import SVC
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Settings to improve readability
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)

# %%
# Load the dataset
df = pd.read_csv("creditcard.csv")  # Replace with your local file path if needed

# Preview first few rows
df.head(25)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
# Shape of the dataset
print("Total Rows:", df.shape[0])
print("Total Columns:", df.shape[1])

# Check data types and non-null counts
df.info()

# Check summary statistics for numeric columns
df.describe()
# Out:
# Total Rows: 284807
# Total Columns: 31
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
# Check total missing values per column
df.isnull().sum().sort_values(ascending=False)
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
x = df.drop(columns = ['Class'])
y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %% [markdown]
# # **Train SVM with:**<br>
#
#     Linear kernel
#     RBF kernel
#     Polynomial kernel
#     Visualize (just a 2D PCA plot to keep it minimal)

# %%
X_pca = PCA(n_components=2).fit_transform(x)

for kernel in ['linear', 'rbf', 'poly']:
    clf = SVC(kernel=kernel)
    clf.fit(x, y)
    acc = clf.score(x, y)
    print(f"{kernel} Kernel Accuracy: {acc:.4f}")

# PCA Scatter
plt.figure()
plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='viridis')
plt.title("PCA Projection of SVM Data")
plt.show()
# Out:
# linear Kernel Accuracy: 0.9986
# rbf Kernel Accuracy: 0.9983
# poly Kernel Accuracy: 0.9983

# %% [markdown]
# The Kernel effect is an easy way that allows algorithms, like SVMs, to handle data that isn't easily separated by a straight line or plane. Instead of transforming the data into a higher-dimensional space where it might be linearly separable , it implicitly calculates how similar data points would be in that higher dimension.
